# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

repo_id = "n4/Qwen3-4B-Instruct-2507-sft_166"
tok = AutoTokenizer.from_pretrained(repo_id, trust_remote_code=True)
model = AutoModelForCausalLM.from_pretrained(repo_id, device_map="auto", trust_remote_code=True)

prompt = "Please output the following information in JSON format: Name=naisy, Age=714"
inputs = tok(prompt, return_tensors="pt").to(model.device)
out = model.generate(**inputs, max_new_tokens=512)
print(tok.decode(out[0], skip_special_tokens=True))
# Out:
# tokenizer_config.json:   0%|          | 0.00/5.62k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/707 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/613 [00:00<?, ?B/s]
# chat_template.jinja:   0%|          | 0.00/2.63k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.54k [00:00<?, ?B/s]
# Skipping import of cpp extensions due to incompatible torch version 2.9.0+cu130 for torchao version 0.15.0+cu130             Please see https://github.com/pytorch/ao/issues/2919 for more info
# model.safetensors.index.json:   0%|          | 0.00/32.9k [00:00<?, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.08G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/187 [00:00<?, ?B/s]
# Please output the following information in JSON format: Name=naisy, Age=714, Gender=male, Height=200, Weight=140, BMI=49.03, Blood pressure=154/97 mmHg, Blood glucose=232 mg/dL, Cholesterol=180 mg/dL, Hemoglobin=14.5 g/dL, White blood cells=14.8, Platelets=450, Platelet volume=13.2, Platelet distribution width=15.8, Neutrophils=6.2, Lymphocytes=3.8, Monocytes=2.7, Eosinophils=1.2, Basophils=0.2, Mean corpuscular volume=114.2 fL, Mean corpuscular hemoglobin=32.5 pg, Mean corpuscular hemoglobin concentration=35.2 g/dL, Red blood cell distribution width=15.3, Hematocrit=45.7%, RBC=4.5 million/mm³, WBC=14.8 million/mm³, Platelets=450 thousand/mm³, Hemoglobin=14.5 g/dL, Hematocrit=45.7%, RBC=4.5 million/mm³, WBC=14.8 million/mm³, Platelets=450 thousand/mm³, HbA1c=6.7%, Urea=38 mg/dL, Creatinine=1.2 mg/dL, Sodium=140 mmol/L, Potassium=5.3 mmol/L, Chloride=104 mmol/L, Carbon dioxide=27 mmol/L, Bicarbonate=23 mmol/L, Glucose=232 mg/dL, Calcium=9.2 mg/dL, Magnesium=1.1 mg/dL, Phosphorus=2.8 mg/dL, Total protein=7.1 g/dL, Albumin=4.5 g/dL, Globulin=2.6 g/dL, Bilirubin=1.5 mg/dL, Total cholesterol=180 mg/dL, LDL cholesterol=100 mg/dL, HDL cholesterol=40 mg/dL, Triglycerides=120 mg/dL, AST=38 U/L, ALT=34 U/L, ALP=110 U
